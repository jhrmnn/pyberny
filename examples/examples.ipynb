# %%
from berny import optimize, geomlib
import numpy as np

# experimental geometry
ethanol = geomlib.loads("""\
9

C	1.1879	-0.3829	0.0000
C	0.0000	0.5526	0.0000
O	-1.1867	-0.2472	0.0000
H	-1.9237	0.3850	0.0000
H	2.0985	0.2306	0.0000
H	1.1184	-1.0093	0.8869
H	1.1184	-1.0093	-0.8869
H	-0.0227	1.1812	0.8852
H	-0.0227	1.1812	-0.8852
""", 'xyz')

# %%
from berny.solvers import MopacSolver

solver = MopacSolver()
final = optimize(solver, ethanol, steprms=0.01, stepmax=0.05)
# Out:
# 0 Internal coordinates:
# 0 * Number of fragments: 1
# 0 * Number of internal coordinates: 33
# 0 * Number of strong bonds: 8
# 0 * Number of strong angles: 13
# 0 * Number of strong dihedrals: 12
# 1 Energy: -22.8594935081
# 1 Pure RFO step was performed:
# 1 * Trust radius: 0.3
# 1 * Number of negative eigenvalues: 0
# 1 * Lowest eigenvalue: 0.00561
# 1 * lambda: -0.00653
# 1 Quadratic step: RMS: 0.0316, max: 0.0913
# 1 * Predicted energy change: -0.00337
# 1 Total step: RMS: 0.0316, max: 0.0913
# 1 Transformation did not converge in 20 iterations
# 1 * RMS(dcart): 0.0322, RMS(dq): 0.0331
# 1 Convergence criteria:
# 1 * Gradient RMS: 0.00576 > 0.0003 => no
# 1 * Gradient maximum: 0.0103 > 0.00045 => no
# 1 * Step RMS: 0.0331 > 0.01 => no
# 1 * Step maximum: 0.0899 > 0.05 => no
# 2 Energy: -22.8624368355
# 2 Hessian update information:
# 2 * Change: RMS: 0.00295, max: 0.0317
# 2 Trust update: Fletcher's parameter: 0.873
# 2 Linear interpolation:
# 2 * Energies: -22.862437, -22.859494
# 2 * Derivatives: -0.000609, 0.00669
# 2 * Quartic interpolation was performed: t = 0.0899
# 2 * Interpolated energy: -22.862464
# 2 Pure RFO step was performed:
# 2 * Trust radius: 0.3
# 2 * Number of negative eigenvalues: 0
# 2 * Lowest eigenvalue: 0.00561
# 2 * lambda: -0.000327
# 2 Quadratic step: RMS: 0.00581, max: 0.0156
# 2 * Predicted energy change: -0.000164
# 2 Total step: RMS: 0.00556, max: 0.0161
# 2 Transformation did not converge in 20 iterations
# 2 * RMS(dcart): 0.00522, RMS(dq): 0.00543
# 2 Convergence criteria:
# 2 * Gradient RMS: 0.00324 > 0.0003 => no
# 2 * Gradient maximum: 0.0103 > 0.00045 => no
# 2 * Step RMS: 0.00543 < 0.01 => OK
# 2 * Step maximum: 0.0161 < 0.05 => OK
# 3 Energy: -22.8626690971
# 3 Hessian update information:
# 3 * Change: RMS: 0.00633, max: 0.0466
# 3 Trust update: Fletcher's parameter: 1.42
# 3 Linear interpolation:
# 3 * Energies: -22.862669, -22.862437
# 3 * Derivatives: 8.05e-05, 0.000377
# 3 * Quartic interpolation was performed: t = -0.249
# 3 * Interpolated energy: -22.862679
# 3 Pure RFO step was performed:
# 3 * Trust radius: 0.3
# 3 * Number of negative eigenvalues: 0
# 3 * Lowest eigenvalue: 0.00561
# 3 * lambda: -8.11e-05
# 3 Quadratic step: RMS: 0.00405, max: 0.0147
# 3 * Predicted energy change: -4.06e-05
# 3 Total step: RMS: 0.00454, max: 0.0146
# 3 Transformation did not converge in 20 iterations
# 3 * RMS(dcart): 0.00759, RMS(dq): 0.00525
# 3 Convergence criteria:
# 3 * Gradient RMS: 0.00151 > 0.0003 => no
# 3 * Gradient maximum: 0.0051 > 0.00045 => no
# 3 * Step RMS: 0.00525 < 0.01 => OK
# 3 * Step maximum: 0.0146 < 0.05 => OK
# 4 Energy: -22.8627117274
# 4 Hessian update information:
# 4 * Change: RMS: 0.00354, max: 0.0403
# 4 Trust update: Fletcher's parameter: 1.05
# 4 Linear interpolation:
# 4 * Energies: -22.862712, -22.862669
# 4 * Derivatives: -1.27e-05, 0.000103
# 4 * Quartic interpolation was performed: t = 0.123
# 4 * Interpolated energy: -22.862713
# 4 Pure RFO step was performed:
# 4 * Trust radius: 0.3
# 4 * Number of negative eigenvalues: 0
# 4 * Lowest eigenvalue: 0.00547
# 4 * lambda: -1.13e-05
# 4 Quadratic step: RMS: 0.00213, max: 0.00443
# 4 * Predicted energy change: -5.67e-06
# 4 Total step: RMS: 0.00188, max: 0.00486
# 4 Transformation did not converge in 20 iterations
# 4 * RMS(dcart): 0.00459, RMS(dq): 0.00207
# 4 Convergence criteria:
# 4 * Gradient RMS: 0.000254 < 0.0003 => OK
# 4 * Gradient maximum: 0.000629 > 0.00045 => no
# 4 * Step RMS: 0.00207 < 0.01 => OK
# 4 * Step maximum: 0.00548 < 0.05 => OK
# 5 Energy: -22.8627187099
# 5 Hessian update information:
# 5 * Change: RMS: 0.00309, max: 0.0349
# 5 Trust update: Fletcher's parameter: 1.23
# 5 Linear interpolation:
# 5 * Energies: -22.862719, -22.862712
# 5 * Derivatives: 9.66e-07, 1.21e-05
# 5 * Quartic interpolation was performed: t = -0.0688
# 5 * Interpolated energy: -22.862719
# 5 Pure RFO step was performed:
# 5 * Trust radius: 0.3
# 5 * Number of negative eigenvalues: 0
# 5 * Lowest eigenvalue: 0.00521
# 5 * lambda: -1.25e-06
# 5 Quadratic step: RMS: 0.00168, max: 0.00464
# 5 * Predicted energy change: -6.24e-07
# 5 Total step: RMS: 0.00169, max: 0.00456
# 5 Transformation did not converge in 20 iterations
# 5 * RMS(dcart): 0.00477, RMS(dq): 0.00339
# 5 Convergence criteria:
# 5 * Gradient RMS: 0.000104 < 0.0003 => OK
# 5 * Gradient maximum: 0.000335 < 0.00045 => OK
# 5 * Step RMS: 0.00339 < 0.01 => OK
# 5 * Step maximum: 0.0118 < 0.05 => OK
# 5 * All criteria matched

# %%
np.linalg.eigvalsh(ethanol.inertia), np.linalg.eigvalsh(final.inertia)
# Out:
# (array([ 14.32256421,  53.51556794,  61.50783216]),
#  array([ 14.9463199 ,  52.57923511,  61.10485592]))

# %%
from pyscf import gto, dft
from pyscf.geomopt.berny_solver import as_berny_solver

mf = dft.RKS(gto.M(atom=list(ethanol), basis='3-21g', verbose=0))
mf.xc = 'pbe'
solver = as_berny_solver(mf)
final = optimize(solver, ethanol)
# Out:
# Warn: Ipython shell catchs sys.args
# 0 Internal coordinates:
# 0 * Number of fragments: 1
# 0 * Number of internal coordinates: 33
# 0 * Number of strong bonds: 8
# 0 * Number of strong angles: 13
# 0 * Number of strong dihedrals: 12
# 1 Energy: -153.123690366
# 1 Pure RFO step was performed:
# 1 * Trust radius: 0.3
# 1 * Number of negative eigenvalues: 0
# 1 * Lowest eigenvalue: 0.00561
# 1 * lambda: -0.0223
# 1 Quadratic step: RMS: 0.0456, max: 0.113
# 1 * Predicted energy change: -0.0119
# 1 Total step: RMS: 0.0456, max: 0.113
# 1 Transformation did not converge in 20 iterations
# 1 * RMS(dcart): 0.0913, RMS(dq): 0.0563
# 1 Convergence criteria:
# 1 * Gradient RMS: 0.0169 > 0.0003 => no
# 1 * Gradient maximum: 0.057 > 0.00045 => no
# 1 * Step RMS: 0.0563 > 0.0012 => no
# 1 * Step maximum: 0.131 > 0.0018 => no
# 2 Energy: -153.135604418
# 2 Hessian update information:
# 2 * Change: RMS: 0.00423, max: 0.0301
# 2 Trust update: Fletcher's parameter: 1.0
# 2 Linear interpolation:
# 2 * Energies: -153.1356, -153.12369
# 2 * Derivatives: 0.000146, 0.025
# 2 * Quartic interpolation was performed: t = -0.00696
# 2 * Interpolated energy: -153.1356
# 2 Pure RFO step was performed:
# 2 * Trust radius: 0.3
# 2 * Number of negative eigenvalues: 0
# 2 * Lowest eigenvalue: 0.0056
# 2 * lambda: -0.00139
# 2 Quadratic step: RMS: 0.0149, max: 0.049
# 2 * Predicted energy change: -0.000701
# 2 Total step: RMS: 0.015, max: 0.0487
# 2 Transformation did not converge in 20 iterations
# 2 * RMS(dcart): 0.017, RMS(dq): 0.0169
# 2 Convergence criteria:
# 2 * Gradient RMS: 0.00319 > 0.0003 => no
# 2 * Gradient maximum: 0.00684 > 0.00045 => no
# 2 * Step RMS: 0.0169 > 0.0012 => no
# 2 * Step maximum: 0.0486 > 0.0018 => no
# 3 Energy: -153.136206465
# 3 Hessian update information:
# 3 * Change: RMS: 0.0039, max: 0.0376
# 3 Trust update: Fletcher's parameter: 0.859
# 3 Linear interpolation:
# 3 * Energies: -153.13621, -153.1356
# 3 * Derivatives: -0.000194, 0.0014
# 3 * Quartic interpolation was performed: t = 0.122
# 3 * Interpolated energy: -153.13622
# 3 Pure RFO step was performed:
# 3 * Trust radius: 0.3
# 3 * Number of negative eigenvalues: 0
# 3 * Lowest eigenvalue: 0.00549
# 3 * lambda: -0.000156
# 3 Quadratic step: RMS: 0.00518, max: 0.0145
# 3 * Predicted energy change: -7.81e-05
# 3 Total step: RMS: 0.00518, max: 0.0194
# 3 Transformation did not converge in 20 iterations
# 3 * RMS(dcart): 0.00906, RMS(dq): 0.00518
# 3 Convergence criteria:
# 3 * Gradient RMS: 0.00132 > 0.0003 => no
# 3 * Gradient maximum: 0.00451 > 0.00045 => no
# 3 * Step RMS: 0.00518 > 0.0012 => no
# 3 * Step maximum: 0.0194 > 0.0018 => no
# 4 Energy: -153.136286277
# 4 Hessian update information:
# 4 * Change: RMS: 0.00311, max: 0.0217
# 4 Trust update: Fletcher's parameter: 1.02
# 4 Linear interpolation:
# 4 * Energies: -153.13629, -153.13621
# 4 * Derivatives: -1.84e-05, 0.00018
# 4 * Quartic interpolation was performed: t = 0.0953
# 4 * Interpolated energy: -153.13629
# 4 Pure RFO step was performed:
# 4 * Trust radius: 0.3
# 4 * Number of negative eigenvalues: 0
# 4 * Lowest eigenvalue: 0.00549
# 4 * lambda: -9.34e-06
# 4 Quadratic step: RMS: 0.00146, max: 0.00261
# 4 * Predicted energy change: -4.67e-06
# 4 Total step: RMS: 0.00154, max: 0.00289
# 4 Transformation did not converge in 20 iterations
# 4 * RMS(dcart): 0.00264, RMS(dq): 0.00126
# 4 Convergence criteria:
# 4 * Gradient RMS: 0.000453 > 0.0003 => no
# 4 * Gradient maximum: 0.00121 > 0.00045 => no
# 4 * Step RMS: 0.00126 > 0.0012 => no
# 4 * Step maximum: 0.00289 > 0.0018 => no
# 5 Energy: -153.13629241
# 5 Hessian update information:
# 5 * Change: RMS: 0.00422, max: 0.03
# 5 Trust update: Fletcher's parameter: 1.31
# 5 Linear interpolation:
# 5 * Energies: -153.13629, -153.13629
# 5 * Derivatives: 1.75e-06, 1.09e-05
# 5 * Quartic interpolation was performed: t = -0.226
# 5 * Interpolated energy: -153.13629
# 5 Pure RFO step was performed:
# 5 * Trust radius: 0.3
# 5 * Number of negative eigenvalues: 0
# 5 * Lowest eigenvalue: 0.00548
# 5 * lambda: -9.14e-07
# 5 Quadratic step: RMS: 0.00112, max: 0.00257
# 5 * Predicted energy change: -4.57e-07
# 5 Total step: RMS: 0.00118, max: 0.00267
# 5 Transformation did not converge in 20 iterations
# 5 * RMS(dcart): 0.00395, RMS(dq): 0.000416
# 5 Convergence criteria:
# 5 * Gradient RMS: 0.000172 < 0.0003 => OK
# 5 * Gradient maximum: 0.000534 > 0.00045 => no
# 5 * Step RMS: 0.000416 < 0.0012 => OK
# 5 * Step maximum: 0.000972 < 0.0018 => OK
# 6 Energy: -153.13629286
# 6 Hessian update information:
# 6 * Change: RMS: 0.00418, max: 0.0541
# 6 Trust update: Fletcher's parameter: 0.985
# 6 Linear interpolation:
# 6 * Energies: -153.13629, -153.13629
# 6 * Derivatives: 2.18e-07, 1.08e-06
# 6 * No fit succeeded, staying in new point
# 6 Pure RFO step was performed:
# 6 * Trust radius: 0.3
# 6 * Number of negative eigenvalues: 0
# 6 * Lowest eigenvalue: 0.00538
# 6 * lambda: -3.98e-07
# 6 Quadratic step: RMS: 0.00127, max: 0.00299
# 6 * Predicted energy change: -1.99e-07
# 6 Total step: RMS: 0.00127, max: 0.00299
# 6 Transformation did not converge in 20 iterations
# 6 * RMS(dcart): 0.00437, RMS(dq): 0.000172
# 6 Convergence criteria:
# 6 * Gradient RMS: 5.32e-05 < 0.0003 => OK
# 6 * Gradient maximum: 0.000165 < 0.00045 => OK
# 6 * Step RMS: 0.000172 < 0.0012 => OK
# 6 * Step maximum: 0.000545 < 0.0018 => OK
# 6 * All criteria matched

# %%
np.linalg.eigvalsh(ethanol.inertia), np.linalg.eigvalsh(final.inertia)
# Out:
# (array([ 14.32256421,  53.51556794,  61.50783216]),
#  array([ 15.97211705,  56.93024039,  66.279842  ]))
